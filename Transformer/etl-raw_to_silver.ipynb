# %% [markdown]
# # Job for data transformation
#
# Este notebook documenta a etapa de transformação de dados da camada Silver, que sucede a extração/ingestão de um relatório institucional de insucesso acadêmico exportado em formato Excel. O arquivo de origem, preservado na camada Bronze com abas por semestre, é lido integralmente e preparado para análise. As transformações incluem a remoção de linhas de rodapé não informativas, o descarte de atributos sem utilidade analítica, a tipagem explícita de identificadores textuais e contagens inteiras, a criação de variáveis derivadas que representem o semestre de oferta e o departamento de origem, bem como a concatenação das diferentes abas em um único conjunto de dados para análise longitudinal.
#
# Do ponto de vista de modelagem, adota-se granularidade por disciplina e semestre, de modo que a combinação de Código e Semestre identifique de forma inequívoca cada registro. A derivação do Departamento a partir do prefixo do Código viabiliza recortes organizacionais consistentes e comparações entre áreas. A padronização de tipos com a explicitação de strings para identificadores e inteiros para contagens evita ambiguidades e reduz o risco de erros durante operações de junção e agregação. Além disso, a imutabilidade por partição temporal é preservada: cada semestre é processado individualmente e, em seguida, incorporado ao conjunto consolidado, o que facilita auditoria e reprodutibilidade.
#
# A governança do processo é apoiada por verificações intermediárias sobre esquemas e contagens, garantindo rastreabilidade das alterações e coerência entre as fontes. Ao final, o resultado é materializado em um arquivo CSV padronizado, `lista-insucesso-processed.csv`, com separador ponto e vírgula, pronto para consumo pelas rotinas de análise e visualização. Reconhece-se, por fim, que a qualidade da análise depende da consistência do arquivo de origem e que investigações causais sobre o insucesso exigiriam variáveis adicionais não contempladas neste relatório; entretanto, a estruturação aqui adotada estabelece uma base sólida para monitoramento perene, comparabilidade entre semestres e expansão futura do escopo analítico.

# %%
# Visão geral programática do Bronze (executar antes das transformações)
import pandas as pd

# Carrega todas as abas
_all = pd.read_excel("../Data-Layer/raw/Relatorio-Lista-Insucesso.xlsx", sheet_name=None)

# Lista de abas e formas
print("Abas:", list(_all.keys()))
for k, df in _all.items():
    print(f"\n--- {k} ---")
    print("shape:", df.shape)
    print("colunas:", list(df.columns))
    print(df.dtypes)

# Exemplo de checagem rápida de nulos por aba
for k, df in _all.items():
    miss = df.isna().sum()
    miss = miss[miss>0]
    if not miss.empty:
        print(f"\nNulos em {k}:\n{miss}")

# Mostra amostra das três primeiras linhas da primeira aba
first_sheet = next(iter(_all))
_all[first_sheet].head(3)
# Out:
# Abas: ['2025.1', '2024.2', '2024.1', '2023.2']
#
# --- 2025.1 ---
# shape: (150, 13)
# colunas: ['Código', 'Nome', 'Pólo', 'Turmas', 'Discentes', 'Cancelamentos', 'Reprovações Média', 'Reprovações Nota', 'Reprovações Falta', 'Reprovações Média e Falta', 'Reprovações Nota e Falta', 'Trancamentos', 'Total Insucesso']
# Código                        object
# Nome                          object
# Pólo                         float64
# Turmas                         int64
# Discentes                      int64
# Cancelamentos                  int64
# Reprovações Média              int64
# Reprovações Nota               int64
# Reprovações Falta              int64
# Reprovações Média e Falta      int64
# Reprovações Nota e Falta       int64
# Trancamentos                   int64
# Total Insucesso                int64
# dtype: object
#
# --- 2024.2 ---
# shape: (164, 13)
# colunas: ['Código', 'Nome', 'Pólo', 'Turmas', 'Discentes', 'Cancelamentos', 'Reprovações Média', 'Reprovações Nota', 'Reprovações Falta', 'Reprovações Média e Falta', 'Reprovações Nota e Falta', 'Trancamentos', 'Total Insucesso']
# Código                        object
# Nome                          object
# Pólo                         float64
# Turmas                         int64
# Discentes                      int64
# Cancelamentos                  int64
# Reprovações Média              int64
# Reprovações Nota               int64
# Reprovações Falta              int64
# Reprovações Média e Falta      int64
# Reprovações Nota e Falta       int64
# Trancamentos                   int64
# Total Insucesso                int64
# dtype: object
#
# --- 2024.1 ---
# shape: (146, 13)
# colunas: ['Código', 'Nome', 'Pólo', 'Turmas', 'Discentes', 'Cancelamentos', 'Reprovações Média', 'Reprovações Nota', 'Reprovações Falta', 'Reprovações Média e Falta', 'Reprovações Nota e Falta', 'Trancamentos', 'Total Insucesso']
# Código                        object
# Nome                          object
# Pólo                         float64
# Turmas                         int64
# Discentes                      int64
# Cancelamentos                  int64
# Reprovações Média              int64
# Reprovações Nota               int64
# Reprovações Falta              int64
# Reprovações Média e Falta      int64
# Reprovações Nota e Falta       int64
# Trancamentos                   int64
# Total Insucesso                int64
# dtype: object
#
# --- 2023.2 ---
# shape: (154, 13)
# colunas: ['Código', 'Nome', 'Pólo', 'Turmas', 'Discentes', 'Cancelamentos', 'Reprovações Média', 'Reprovações Nota', 'Reprovações Falta', 'Reprovações Média e Falta', 'Reprovações Nota e Falta', 'Trancamentos', 'Total Insucesso']
# Código                        object
# Nome                          object
# Pólo                         float64
# Turmas                         int64
# Discentes                      int64
# Cancelamentos                  int64
# Reprovações Média              int64
# Reprovações Nota               int64
# Reprovações Falta              int64
# Reprovações Média e Falta      int64
# Reprovações Nota e Falta       int64
# Trancamentos                   int64
# Total Insucesso                int64
# dtype: object
#
# Nulos em 2025.1:
# Nome      1
# Pólo    150
# dtype: int64
#
# Nulos em 2024.2:
# Nome      1
# Pólo    164
# dtype: int64
#
# Nulos em 2024.1:
# Nome      1
# Pólo    146
# dtype: int64
#
# Nulos em 2023.2:
# Nome      1
# Pólo    154
# dtype: int64
#     Código                                      Nome  Pólo  Turmas  Discentes  \
# 0  MAT0039                            ALGEBRA LINEAR   NaN       1          1
# 1  CIC0004  ALGORITMOS E PROGRAMAÇÃO DE COMPUTADORES   NaN       5         38
# 2  MAT0045                                 ANALISE 1   NaN       1          1
#
#    Cancelamentos  Reprovações Média  Reprovações Nota  Reprovações Falta  \
# 0              0                  0                 0                  0
# 1              3                  5                 0                  2
# 2              0                  0                 0                  0
#
#    Reprovações Média e Falta  Reprovações Nota e Falta  Trancamentos  \
# 0                          0                         0             1
# 1                          0                         0             1
# 2                          0                         0             1
#
#    Total Insucesso
# 0                1
# 1               11
# 2                1

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Read data

# %%
dataframes_all_sheets = pd.read_excel("../bronze/Relatorio-Lista-Insucesso.xlsx", sheet_name=None)
dataframes_all_sheets_automotiva = pd.read_excel("../bronze/Relatorio-Lista-Insucesso-Automotiva.xlsx", sheet_name=None)

# %%
for dataframe in dataframes_all_sheets:
    dataframes_all_sheets[dataframe].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     150 non-null    object
#  1   Nome                       149 non-null    object
#  2   Pólo                       0 non-null      float64
#  3   Turmas                     150 non-null    int64
#  4   Discentes                  150 non-null    int64
#  5   Cancelamentos              150 non-null    int64
#  6   Reprovações Média          150 non-null    int64
#  7   Reprovações Nota           150 non-null    int64
#  8   Reprovações Falta          150 non-null    int64
#  9   Reprovações Média e Falta  150 non-null    int64
#  10  Reprovações Nota e Falta   150 non-null    int64
#  11  Trancamentos               150 non-null    int64
#  12  Total Insucesso            150 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 15.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     164 non-null    object
#  1   Nome                       163 non-null    object
#  2   Pólo                       0 non-null      float64
#  3   Turmas                     164 non-null    int64
#  4   Discentes                  164 non-null    int64
#  5   Cancelamentos              164 non-null    int64
#  6   Reprovações Média          164 non-null    int64
#  7   Reprovações Nota           164 non-null    int64
#  8   Reprovações Falta          164 non-null    int64
#  9   Reprovações Média e Falta  164 non-null    int64
#  10  Reprovações Nota e Falta   164 non-null    int64
#  11  Trancamentos               164 non-null    int64
#  12  Total Insucesso            164 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 16.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     146 non-null    object
#  1   Nome                       145 non-null    object
#  2   Pólo                       0 non-null      float64
#  3   Turmas                     146 non-null    int64
#  4   Discentes                  146 non-null    int64
#  5   Cancelamentos              146 non-null    int64
#  6   Reprovações Média          146 non-null    int64
#  7   Reprovações Nota           146 non-null    int64
#  8   Reprovações Falta          146 non-null    int64
#  9   Reprovações Média e Falta  146 non-null    int64
#  10  Reprovações Nota e Falta   146 non-null    int64
#  11  Trancamentos               146 non-null    int64
#  12  Total Insucesso            146 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 15.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     154 non-null    object
#  1   Nome                       153 non-null    object
#  2   Pólo                       0 non-null      float64
#  3   Turmas                     154 non-null    int64
#  4   Discentes                  154 non-null    int64
#  5   Cancelamentos              154 non-null    int64
#  6   Reprovações Média          154 non-null    int64
#  7   Reprovações Nota           154 non-null    int64
#  8   Reprovações Falta          154 non-null    int64
#  9   Reprovações Média e Falta  154 non-null    int64
#  10  Reprovações Nota e Falta   154 non-null    int64
#  11  Trancamentos               154 non-null    int64
#  12  Total Insucesso            154 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# ## Transform data

# %% [markdown]
# ### Create an empty dataframe

# %%
finalDataframe = pd.DataFrame()

# %% [markdown]
# ### Dataframe 2023.2

# %%
dataframe1 = dataframes_all_sheets['2023.2']
dataframe1.tail()
# Out:
#       Código                                               Nome  Pólo  Turmas  \
# 149  FGA0261                    TÓPICOS ESPECIAIS EM ELETRONICA   NaN       1
# 150  FGA0054  TÓPICOS ESPECIAIS EM GOVERNANÇA DE TECNOLOGIA ...   NaN       1
# 151  FGA0053                   TÓPICOS ESPECIAIS EM PROGRAMAÇÃO   NaN       2
# 152  DSC0172            VIGILÂNCIA EPIDEMIOLÓGICA PARTICIPATIVA   NaN       4
# 153   Total:                                                NaN   NaN     327
#
#      Discentes  Cancelamentos  Reprovações Média  Reprovações Nota  \
# 149          2              2                  0                 0
# 150         59              4                  1                 0
# 151         94              3                  9                 0
# 152        243              8                  2                 0
# 153       7369            232               1110                 0
#
#      Reprovações Falta  Reprovações Média e Falta  Reprovações Nota e Falta  \
# 149                  0                          0                         0
# 150                  0                          0                         0
# 151                  7                          0                         0
# 152                  0                          0                         0
# 153                316                          0                         0
#
#      Trancamentos  Total Insucesso
# 149             0                2
# 150             6               11
# 151            28               47
# 152             1               11
# 153           547             2205

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 154 entries, 0 to 153
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     154 non-null    object
#  1   Nome                       153 non-null    object
#  2   Pólo                       0 non-null      float64
#  3   Turmas                     154 non-null    int64
#  4   Discentes                  154 non-null    int64
#  5   Cancelamentos              154 non-null    int64
#  6   Reprovações Média          154 non-null    int64
#  7   Reprovações Nota           154 non-null    int64
#  8   Reprovações Falta          154 non-null    int64
#  9   Reprovações Média e Falta  154 non-null    int64
#  10  Reprovações Nota e Falta   154 non-null    int64
#  11  Trancamentos               154 non-null    int64
#  12  Total Insucesso            154 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# #### Drop last line -> not usable info

# %%
dataframe1 = dataframe1.iloc[:-1]

# %% [markdown]
# #### Drop 'Pólo' column

# %%
dataframe1 = dataframe1.drop(columns=['Pólo'])

# %% [markdown]
# #### Parse columns 'Código' and 'Nome' to string

# %%
dataframe1['Código'] = dataframe1['Código'].astype("string")
dataframe1['Nome'] = dataframe1['Nome'].astype("string")

# %% [markdown]
# #### Create a column for the semester

# %%
dataframe1['Semestre'] = "2023.2"
dataframe1['Semestre'] = dataframe1['Semestre'].astype("string")

# %% [markdown]
# #### Create a column for the origin department

# %%
dataframe1['Departamento'] = dataframe1['Código'].str[:3]

# %% [markdown]
# #### Actual state of the dataframe

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     153 non-null    string
#  1   Nome                       153 non-null    string
#  2   Turmas                     153 non-null    int64
#  3   Discentes                  153 non-null    int64
#  4   Cancelamentos              153 non-null    int64
#  5   Reprovações Média          153 non-null    int64
#  6   Reprovações Nota           153 non-null    int64
#  7   Reprovações Falta          153 non-null    int64
#  8   Reprovações Média e Falta  153 non-null    int64
#  9   Reprovações Nota e Falta   153 non-null    int64
#  10  Trancamentos               153 non-null    int64
#  11  Total Insucesso            153 non-null    int64
#  12  Semestre                   153 non-null    string
#  13  Departamento               153 non-null    string
# dtypes: int64(10), string(4)
# memory usage: 16.9 KB

# %%
dataframe1.tail()
# Out:
#       Código                                               Nome  Turmas  \
# 148  JOR0107                 TÓPICOS ESPECIAIS EM COMUNICAÇÃO 1       1
# 149  FGA0261                    TÓPICOS ESPECIAIS EM ELETRONICA       1
# 150  FGA0054  TÓPICOS ESPECIAIS EM GOVERNANÇA DE TECNOLOGIA ...       1
# 151  FGA0053                   TÓPICOS ESPECIAIS EM PROGRAMAÇÃO       2
# 152  DSC0172            VIGILÂNCIA EPIDEMIOLÓGICA PARTICIPATIVA       4
#
#      Discentes  Cancelamentos  Reprovações Média  Reprovações Nota  \
# 148          1              0                  0                 0
# 149          2              2                  0                 0
# 150         59              4                  1                 0
# 151         94              3                  9                 0
# 152        243              8                  2                 0
#
#      Reprovações Falta  Reprovações Média e Falta  Reprovações Nota e Falta  \
# 148                  0                          0                         0
# 149                  0                          0                         0
# 150                  0                          0                         0
# 151                  7                          0                         0
# 152                  0                          0                         0
#
#      Trancamentos  Total Insucesso Semestre Departamento
# 148             0                0   2023.2          JOR
# 149             0                2   2023.2          FGA
# 150             6               11   2023.2          FGA
# 151            28               47   2023.2          FGA
# 152             1               11   2023.2          DSC

# %% [markdown]
# #### Add transformed data to the final dataframe

# %%
finalDataframe = dataframe1.copy()

# %% [markdown]
# ### Dataframe 2024.1

# %%
dataframe1 = dataframes_all_sheets['2024.1']
dataframe1.tail()
# Out:
#       Código                                      Nome  Pólo  Turmas  \
# 141  FGA0034  TÓPICOS ESPECIAIS EM MATEMÁTICA APLICADA   NaN       1
# 142  FGA0053          TÓPICOS ESPECIAIS EM PROGRAMAÇÃO   NaN       1
# 143  SER0113                  TRABALHO E SOCIABILIDADE   NaN       1
# 144  DSC0172   VIGILÂNCIA EPIDEMIOLÓGICA PARTICIPATIVA   NaN       1
# 145   Total:                                       NaN   NaN     304
#
#      Discentes  Cancelamentos  Reprovações Média  Reprovações Nota  \
# 141         14              0                  0                 0
# 142         29              1                  6                 0
# 143          1              0                  0                 0
# 144        373             12                  9                 0
# 145       6209            299                223                 0
#
#      Reprovações Falta  Reprovações Média e Falta  Reprovações Nota e Falta  \
# 141                  0                          0                         0
# 142                  1                          0                         0
# 143                  0                          0                         0
# 144                  0                          0                         0
# 145                 97                          0                         0
#
#      Trancamentos  Total Insucesso
# 141             0                0
# 142             0                8
# 143             0                0
# 144             0               21
# 145             0              619

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     146 non-null    object
#  1   Nome                       145 non-null    object
#  2   Pólo                       0 non-null      float64
#  3   Turmas                     146 non-null    int64
#  4   Discentes                  146 non-null    int64
#  5   Cancelamentos              146 non-null    int64
#  6   Reprovações Média          146 non-null    int64
#  7   Reprovações Nota           146 non-null    int64
#  8   Reprovações Falta          146 non-null    int64
#  9   Reprovações Média e Falta  146 non-null    int64
#  10  Reprovações Nota e Falta   146 non-null    int64
#  11  Trancamentos               146 non-null    int64
#  12  Total Insucesso            146 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 15.0+ KB

# %% [markdown]
# #### Drop last line -> not usable info

# %%
dataframe1 = dataframe1.iloc[:-1]

# %% [markdown]
# #### Drop 'Pólo' column

# %%
dataframe1 = dataframe1.drop(columns=['Pólo'])

# %% [markdown]
# #### Parse columns 'Código' and 'Nome' to string

# %%
dataframe1['Código'] = dataframe1['Código'].astype("string")
dataframe1['Nome'] = dataframe1['Nome'].astype("string")

# %% [markdown]
# #### Create a column for the semester

# %%
dataframe1['Semestre'] = "2024.1"
dataframe1['Semestre'] = dataframe1['Semestre'].astype("string")

# %% [markdown]
# #### Create a column for the origin department

# %%
dataframe1['Departamento'] = dataframe1['Código'].str[:3]

# %% [markdown]
# #### Actual state of the dataframe

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     145 non-null    string
#  1   Nome                       145 non-null    string
#  2   Turmas                     145 non-null    int64
#  3   Discentes                  145 non-null    int64
#  4   Cancelamentos              145 non-null    int64
#  5   Reprovações Média          145 non-null    int64
#  6   Reprovações Nota           145 non-null    int64
#  7   Reprovações Falta          145 non-null    int64
#  8   Reprovações Média e Falta  145 non-null    int64
#  9   Reprovações Nota e Falta   145 non-null    int64
#  10  Trancamentos               145 non-null    int64
#  11  Total Insucesso            145 non-null    int64
#  12  Semestre                   145 non-null    string
#  13  Departamento               145 non-null    string
# dtypes: int64(10), string(4)
# memory usage: 16.0 KB

# %%
dataframe1.tail()
# Out:
#       Código                                               Nome  Turmas  \
# 140  FGA0054  TÓPICOS ESPECIAIS EM GOVERNANÇA DE TECNOLOGIA ...       1
# 141  FGA0034           TÓPICOS ESPECIAIS EM MATEMÁTICA APLICADA       1
# 142  FGA0053                   TÓPICOS ESPECIAIS EM PROGRAMAÇÃO       1
# 143  SER0113                           TRABALHO E SOCIABILIDADE       1
# 144  DSC0172            VIGILÂNCIA EPIDEMIOLÓGICA PARTICIPATIVA       1
#
#      Discentes  Cancelamentos  Reprovações Média  Reprovações Nota  \
# 140         43              3                  0                 0
# 141         14              0                  0                 0
# 142         29              1                  6                 0
# 143          1              0                  0                 0
# 144        373             12                  9                 0
#
#      Reprovações Falta  Reprovações Média e Falta  Reprovações Nota e Falta  \
# 140                  1                          0                         0
# 141                  0                          0                         0
# 142                  1                          0                         0
# 143                  0                          0                         0
# 144                  0                          0                         0
#
#      Trancamentos  Total Insucesso Semestre Departamento
# 140             0                4   2024.1          FGA
# 141             0                0   2024.1          FGA
# 142             0                8   2024.1          FGA
# 143             0                0   2024.1          SER
# 144             0               21   2024.1          DSC

# %% [markdown]
# #### Add transformed data to the final dataframe

# %%
finalDataframe = pd.concat([finalDataframe, dataframe1], ignore_index=True)

# %% [markdown]
# ### Dataframe 2024.2

# %%
dataframe1 = dataframes_all_sheets['2024.2']
dataframe1.tail()
# Out:
#       Código                                               Nome  Pólo  Turmas  \
# 159  FGA0053                   TÓPICOS ESPECIAIS EM PROGRAMAÇÃO   NaN       1
# 160  DPG1322  TÓPICOS ESPECIAIS EM SISTEMAS BIOMÉDICOS ELETR...   NaN       1
# 161  CEM0015                   UNIVERSIDADE, SOCIEDADE E ESTADO   NaN       1
# 162  DSC0172            VIGILÂNCIA EPIDEMIOLÓGICA PARTICIPATIVA   NaN       1
# 163   Total:                                                NaN   NaN     324
#
#      Discentes  Cancelamentos  Reprovações Média  Reprovações Nota  \
# 159        111              1                 37                 0
# 160          1              0                  0                 0
# 161          2              0                  0                 0
# 162        303              1                 14                 0
# 163       7387            206                892                 0
#
#      Reprovações Falta  Reprovações Média e Falta  Reprovações Nota e Falta  \
# 159                  8                          0                         0
# 160                  0                          0                         0
# 161                  1                          0                         0
# 162                  0                          0                         0
# 163                263                          0                         0
#
#      Trancamentos  Total Insucesso
# 159            25               71
# 160             0                0
# 161             0                1
# 162             3               18
# 163           523             1884

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     164 non-null    object
#  1   Nome                       163 non-null    object
#  2   Pólo                       0 non-null      float64
#  3   Turmas                     164 non-null    int64
#  4   Discentes                  164 non-null    int64
#  5   Cancelamentos              164 non-null    int64
#  6   Reprovações Média          164 non-null    int64
#  7   Reprovações Nota           164 non-null    int64
#  8   Reprovações Falta          164 non-null    int64
#  9   Reprovações Média e Falta  164 non-null    int64
#  10  Reprovações Nota e Falta   164 non-null    int64
#  11  Trancamentos               164 non-null    int64
#  12  Total Insucesso            164 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 16.8+ KB

# %% [markdown]
# #### Drop last line -> not usable info

# %%
dataframe1 = dataframe1.iloc[:-1]

# %% [markdown]
# #### Drop 'Pólo' column

# %%
dataframe1 = dataframe1.drop(columns=['Pólo'])

# %% [markdown]
# #### Parse columns 'Código' and 'Nome' to string

# %%
dataframe1['Código'] = dataframe1['Código'].astype("string")
dataframe1['Nome'] = dataframe1['Nome'].astype("string")

# %% [markdown]
# #### Create a column for the semester

# %%
dataframe1['Semestre'] = "2024.2"
dataframe1['Semestre'] = dataframe1['Semestre'].astype("string")

# %% [markdown]
# #### Create a column for the origin department

# %%
dataframe1['Departamento'] = dataframe1['Código'].str[:3]

# %% [markdown]
# #### Actual state of the dataframe

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     163 non-null    string
#  1   Nome                       163 non-null    string
#  2   Turmas                     163 non-null    int64
#  3   Discentes                  163 non-null    int64
#  4   Cancelamentos              163 non-null    int64
#  5   Reprovações Média          163 non-null    int64
#  6   Reprovações Nota           163 non-null    int64
#  7   Reprovações Falta          163 non-null    int64
#  8   Reprovações Média e Falta  163 non-null    int64
#  9   Reprovações Nota e Falta   163 non-null    int64
#  10  Trancamentos               163 non-null    int64
#  11  Total Insucesso            163 non-null    int64
#  12  Semestre                   163 non-null    string
#  13  Departamento               163 non-null    string
# dtypes: int64(10), string(4)
# memory usage: 18.0 KB

# %%
dataframe1.tail()
# Out:
#       Código                                               Nome  Turmas  \
# 158  FGA0034           TÓPICOS ESPECIAIS EM MATEMÁTICA APLICADA       1
# 159  FGA0053                   TÓPICOS ESPECIAIS EM PROGRAMAÇÃO       1
# 160  DPG1322  TÓPICOS ESPECIAIS EM SISTEMAS BIOMÉDICOS ELETR...       1
# 161  CEM0015                   UNIVERSIDADE, SOCIEDADE E ESTADO       1
# 162  DSC0172            VIGILÂNCIA EPIDEMIOLÓGICA PARTICIPATIVA       1
#
#      Discentes  Cancelamentos  Reprovações Média  Reprovações Nota  \
# 158         27              1                  0                 0
# 159        111              1                 37                 0
# 160          1              0                  0                 0
# 161          2              0                  0                 0
# 162        303              1                 14                 0
#
#      Reprovações Falta  Reprovações Média e Falta  Reprovações Nota e Falta  \
# 158                  0                          0                         0
# 159                  8                          0                         0
# 160                  0                          0                         0
# 161                  1                          0                         0
# 162                  0                          0                         0
#
#      Trancamentos  Total Insucesso Semestre Departamento
# 158             0                1   2024.2          FGA
# 159            25               71   2024.2          FGA
# 160             0                0   2024.2          DPG
# 161             0                1   2024.2          CEM
# 162             3               18   2024.2          DSC

# %% [markdown]
# #### Add transformed data to the final dataframe

# %%
finalDataframe = pd.concat([finalDataframe, dataframe1], ignore_index=True)

# %% [markdown]
# ### Dataframe 2025.1

# %%
dataframe1 = dataframes_all_sheets['2025.1']
dataframe1.tail()
# Out:
#       Código                                               Nome  Pólo  Turmas  \
# 145  FGA0054  TÓPICOS ESPECIAIS EM GOVERNANÇA DE TECNOLOGIA ...   NaN       1
# 146  FGA0053                   TÓPICOS ESPECIAIS EM PROGRAMAÇÃO   NaN       1
# 147  CEM0015                   UNIVERSIDADE, SOCIEDADE E ESTADO   NaN       1
# 148  DSC0172            VIGILÂNCIA EPIDEMIOLÓGICA PARTICIPATIVA   NaN       1
# 149   Total:                                                NaN   NaN     322
#
#      Discentes  Cancelamentos  Reprovações Média  Reprovações Nota  \
# 145         30              0                  0                 0
# 146         32              1                  0                 0
# 147          1              0                  0                 0
# 148        245              8                 11                 0
# 149       6640            202                744                 0
#
#      Reprovações Falta  Reprovações Média e Falta  Reprovações Nota e Falta  \
# 145                  0                          0                         0
# 146                  3                          0                         0
# 147                  1                          0                         0
# 148                  0                          0                         0
# 149                210                          0                         0
#
#      Trancamentos  Total Insucesso
# 145             1                1
# 146            11               15
# 147             0                1
# 148             5               24
# 149           578             1734

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     150 non-null    object
#  1   Nome                       149 non-null    object
#  2   Pólo                       0 non-null      float64
#  3   Turmas                     150 non-null    int64
#  4   Discentes                  150 non-null    int64
#  5   Cancelamentos              150 non-null    int64
#  6   Reprovações Média          150 non-null    int64
#  7   Reprovações Nota           150 non-null    int64
#  8   Reprovações Falta          150 non-null    int64
#  9   Reprovações Média e Falta  150 non-null    int64
#  10  Reprovações Nota e Falta   150 non-null    int64
#  11  Trancamentos               150 non-null    int64
#  12  Total Insucesso            150 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 15.4+ KB

# %% [markdown]
# #### Drop last line -> not usable info

# %%
dataframe1 = dataframe1.iloc[:-1]

# %% [markdown]
# #### Drop 'Pólo' column

# %%
dataframe1 = dataframe1.drop(columns=['Pólo'])

# %% [markdown]
# #### Parse columns 'Código' and 'Nome' to string

# %%
dataframe1['Código'] = dataframe1['Código'].astype("string")
dataframe1['Nome'] = dataframe1['Nome'].astype("string")

# %% [markdown]
# #### Create a column for the semester

# %%
dataframe1['Semestre'] = "2025.1"
dataframe1['Semestre'] = dataframe1['Semestre'].astype("string")

# %% [markdown]
# #### Create a column for the origin department

# %%
dataframe1['Departamento'] = dataframe1['Código'].str[:3]

# %% [markdown]
# #### Actual state of the dataframe

# %%
dataframe1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     149 non-null    string
#  1   Nome                       149 non-null    string
#  2   Turmas                     149 non-null    int64
#  3   Discentes                  149 non-null    int64
#  4   Cancelamentos              149 non-null    int64
#  5   Reprovações Média          149 non-null    int64
#  6   Reprovações Nota           149 non-null    int64
#  7   Reprovações Falta          149 non-null    int64
#  8   Reprovações Média e Falta  149 non-null    int64
#  9   Reprovações Nota e Falta   149 non-null    int64
#  10  Trancamentos               149 non-null    int64
#  11  Total Insucesso            149 non-null    int64
#  12  Semestre                   149 non-null    string
#  13  Departamento               149 non-null    string
# dtypes: int64(10), string(4)
# memory usage: 16.4 KB

# %%
dataframe1.tail()
# Out:
#       Código                                               Nome  Turmas  \
# 144  FGA0214         TÓPICOS ESPECIAIS EM ENGENHARIA AUTOMOTIVA       1
# 145  FGA0054  TÓPICOS ESPECIAIS EM GOVERNANÇA DE TECNOLOGIA ...       1
# 146  FGA0053                   TÓPICOS ESPECIAIS EM PROGRAMAÇÃO       1
# 147  CEM0015                   UNIVERSIDADE, SOCIEDADE E ESTADO       1
# 148  DSC0172            VIGILÂNCIA EPIDEMIOLÓGICA PARTICIPATIVA       1
#
#      Discentes  Cancelamentos  Reprovações Média  Reprovações Nota  \
# 144          1              0                  0                 0
# 145         30              0                  0                 0
# 146         32              1                  0                 0
# 147          1              0                  0                 0
# 148        245              8                 11                 0
#
#      Reprovações Falta  Reprovações Média e Falta  Reprovações Nota e Falta  \
# 144                  0                          0                         0
# 145                  0                          0                         0
# 146                  3                          0                         0
# 147                  1                          0                         0
# 148                  0                          0                         0
#
#      Trancamentos  Total Insucesso Semestre Departamento
# 144             1                1   2025.1          FGA
# 145             1                1   2025.1          FGA
# 146            11               15   2025.1          FGA
# 147             0                1   2025.1          CEM
# 148             5               24   2025.1          DSC

# %% [markdown]
# #### Add transformed data to the final dataframe

# %%
finalDataframe = pd.concat([finalDataframe, dataframe1], ignore_index=True)
finalDataframe['Curso'] = "Software"
finalDataframe['Curso'] = finalDataframe['Curso'].astype("string")

# %%
finalDataframe.to_csv('./lista-insucesso-processed-software.csv', sep=';',index=False)

# %% [markdown]
# ### Make transformations for automotiva

# %%
semesters = ['2023.2', '2024.1','2024.2','2025.1']

for semester in semesters:
    dataframe1 = dataframes_all_sheets_automotiva[semester]
    dataframe1 = dataframe1.iloc[:-1]
    dataframe1 = dataframe1.drop(columns=['Pólo'])
    dataframe1['Código'] = dataframe1['Código'].astype("string")
    dataframe1['Nome'] = dataframe1['Nome'].astype("string")
    dataframe1['Semestre'] = semester
    dataframe1['Semestre'] = dataframe1['Semestre'].astype("string")
    dataframe1['Departamento'] = dataframe1['Código'].str[:3]
    dataframe1['Curso'] = "Automotiva"
    dataframe1['Curso'] = dataframe1['Curso'].astype("string")
    print(dataframe1.info())
    finalDataframe = pd.concat([finalDataframe, dataframe1], ignore_index=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     82 non-null     string
#  1   Nome                       82 non-null     string
#  2   Turmas                     82 non-null     int64
#  3   Discentes                  82 non-null     int64
#  4   Cancelamentos              82 non-null     int64
#  5   Reprovações Média          82 non-null     int64
#  6   Reprovações Nota           82 non-null     int64
#  7   Reprovações Falta          82 non-null     int64
#  8   Reprovações Média e Falta  82 non-null     int64
#  9   Reprovações Nota e Falta   82 non-null     int64
#  10  Trancamentos               82 non-null     int64
#  11  Total Insucesso            82 non-null     int64
#  12  Semestre                   82 non-null     string
#  13  Departamento               82 non-null     string
#  14  Curso                      82 non-null     string
# dtypes: int64(10), string(5)
# memory usage: 9.7 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     75 non-null     string
#  1   Nome                       75 non-null     string
#  2   Turmas                     75 non-null     int64
#  3   Discentes                  75 non-null     int64
#  4   Cancelamentos              75 non-null     int64
#  5   Reprovações Média          75 non-null     int64
#  6   Reprovações Nota           75 non-null     int64
#  7   Reprovações Falta          75 non-null     int64
#  8   Reprovações Média e Falta  75 non-null     int64
#  9   Reprovações Nota e Falta   75 non-null     int64
#  10  Trancamentos               75 non-null     int64
#  11  Total Insucesso            75 non-null     int64
#  12  Semestre                   75 non-null     string
#  13  Departamento               75 non-null     string
#  14  Curso                      75 non-null     string
# dtypes: int64(10), string(5)
# memory usage: 8.9 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     72 non-null     string
#  1   Nome                       72 non-null     string
#  2   Turmas                     72 non-null     int64
#  3   Discentes                  72 non-null     int64
#  4   Cancelamentos              72 non-null     int64
#  5   Reprovações Média          72 non-null     int64
#  6   Reprovações Nota           72 non-null     int64
#  7   Reprovações Falta          72 non-null     int64
#  8   Reprovações Média e Falta  72 non-null     int64
#  9   Reprovações Nota e Falta   72 non-null     int64
#  10  Trancamentos               72 non-null     int64
#  11  Total Insucesso            72 non-null     int64
#  12  Semestre                   72 non-null     string
#  13  Departamento               72 non-null     string
#  14  Curso                      72 non-null     string
# dtypes: int64(10), string(5)
# memory usage: 8.6 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     78 non-null     string
#  1   Nome                       78 non-null     string
#  2   Turmas                     78 non-null     int64
#  3   Discentes                  78 non-null     int64
#  4   Cancelamentos              78 non-null     int64
#  5   Reprovações Média          78 non-null     int64
#  6   Reprovações Nota           78 non-null     int64
#  7   Reprovações Falta          78 non-null     int64
#  8   Reprovações Média e Falta  78 non-null     int64
#  9   Reprovações Nota e Falta   78 non-null     int64
#  10  Trancamentos               78 non-null     int64
#  11  Total Insucesso            78 non-null     int64
#  12  Semestre                   78 non-null     string
#  13  Departamento               78 non-null     string
#  14  Curso                      78 non-null     string
# dtypes: int64(10), string(5)
# memory usage: 9.3 KB
# None

# %% [markdown]
# ### Final dataframe

# %% [markdown]
# #### Show statistics of the final data

# %%
finalDataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917 entries, 0 to 916
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Código                     917 non-null    string
#  1   Nome                       917 non-null    string
#  2   Turmas                     917 non-null    int64
#  3   Discentes                  917 non-null    int64
#  4   Cancelamentos              917 non-null    int64
#  5   Reprovações Média          917 non-null    int64
#  6   Reprovações Nota           917 non-null    int64
#  7   Reprovações Falta          917 non-null    int64
#  8   Reprovações Média e Falta  917 non-null    int64
#  9   Reprovações Nota e Falta   917 non-null    int64
#  10  Trancamentos               917 non-null    int64
#  11  Total Insucesso            917 non-null    int64
#  12  Semestre                   917 non-null    string
#  13  Departamento               917 non-null    string
#  14  Curso                      917 non-null    string
# dtypes: int64(10), string(5)
# memory usage: 107.6 KB

# %%
finalDataframe.tail()
# Out:
#       Código                                        Nome  Turmas  Discentes  \
# 912  FGA0119                   TEORIA DEELETROMAGNETISMO       2          3
# 913  FGA0078            TEORIA DE MATERIAIS DECONSTRUÇÃO       2          4
# 914  FGA0088   TEORIA DE SISTEMAS DECONVERSÃO DE ENERGIA       1          1
# 915  FGA0214   TÓPICOS ESPECIAIS EMENGENHARIA AUTOMOTIVA       2         14
# 916  DSC0172  VIGILÂNCIA\nEPIDEMIOLÓGICA \nPARTICIPATIVA       1         11
#
#      Cancelamentos  Reprovações Média  Reprovações Nota  Reprovações Falta  \
# 912              0                  0                 0                  0
# 913              0                  1                 0                  0
# 914              0                  0                 0                  0
# 915              1                  0                 0                  4
# 916              0                  3                 0                  0
#
#      Reprovações Média e Falta  Reprovações Nota e Falta  Trancamentos  \
# 912                          0                         0             1
# 913                          0                         0             1
# 914                          0                         0             0
# 915                          0                         0             5
# 916                          0                         0             1
#
#      Total Insucesso Semestre Departamento       Curso
# 912                1   2025.1          FGA  Automotiva
# 913                2   2025.1          FGA  Automotiva
# 914                0   2025.1          FGA  Automotiva
# 915               10   2025.1          FGA  Automotiva
# 916                4   2025.1          DSC  Automotiva

# %% [markdown]
# ### Transform semester column to the format year-semester

# %%
finalDataframe['Semestre'] = finalDataframe['Semestre'].str.replace('\\.','-', regex=True)

# %% [markdown]
# ## Populate Database

# %% [markdown]
# ### Imports

# %%
import psycopg2
from psycopg2 import sql
import os

# %% [markdown]
# ### Connect Postgres

# %%
DB_HOST = os.getenv("DATABASE_HOST", "localhost")
DB_PORT = os.getenv("DATABASE_PORT", "5432")
DB_USER = os.getenv("DATABASE_USER", "postgres")
DB_PASSWORD = os.getenv("DATABASE_PASSWORD", "postgres123")


conn = psycopg2.connect(
    host=DB_HOST,
    port=DB_PORT,
    user=DB_USER,
    password=DB_PASSWORD
)

# %% [markdown]
# ### Populate Database

# %%
cursor = conn.cursor()

df = finalDataframe

for _, row in df.iterrows():
    cursor.execute("""
        INSERT INTO disciplinas (
            codigo, nome, turmas, discentes, cancelamentos,
            reprovacoesMedia, reprovacoesNota, reprovacoesFalta,
            reprovacoesMediaFalta, reprovacoesNotaFalta, trancamentos,
            insucessos, semestre, departamento, curso
        ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
    """, (
        row['Código'],
        row['Nome'],
        row['Turmas'],
        row['Discentes'],
        row['Cancelamentos'],
        row['Reprovações Média'],
        row['Reprovações Nota'],
        row['Reprovações Falta'],
        row['Reprovações Média e Falta'],
        row['Reprovações Nota e Falta'],
        row['Trancamentos'],
        row['Total Insucesso'],
        row['Semestre'],
        row['Departamento'],
        row['Curso']
    ))

conn.commit()
cursor.close()
conn.close()

# %% [markdown]
# #### Export dataframe to .csv

# %%
finalDataframe.to_csv('./lista-insucesso-processed.csv', sep=';',index=False)
